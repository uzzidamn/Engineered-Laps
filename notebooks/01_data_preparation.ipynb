# %% [markdown]
# # Step 1: Data Preparation
#
# **Objective:**
# Export historic race session data from FastF1 API for use as the streaming source.
#
# **Instructions:**
# - Extract relevant fields (Speed, LapNumber, Timestamp, DriverID, Compound, etc.) from a FastF1 session
# - Save as CSV, Parquet, or JSON file
# - Validate: File loads without errors, data columns are as expected
# - Calculate data frequency from timestamps

# %%
# Import required libraries
import sys
import os
import importlib
import pandas as pd
import numpy as np
from datetime import datetime

# Add project root directory to path
# Get current working directory
cwd = os.getcwd()
# If we're in notebooks/, go up one level to get project root
if os.path.basename(cwd) == 'notebooks':
    project_root = os.path.dirname(cwd)
else:
    # Otherwise, assume we're already in project root or need to navigate
    project_root = cwd
    # If src doesn't exist here, try going up from notebooks
    if not os.path.exists(os.path.join(project_root, 'src')):
        # Try to find project root by looking for src directory
        current = cwd
        while current != os.path.dirname(current):
            if os.path.exists(os.path.join(current, 'src')):
                project_root = current
                break
            current = os.path.dirname(current)

# Add project root to Python path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Import our modules
from src.data_preparation import (
    load_fastf1_session,
    extract_telemetry_fields,
    export_to_csv,
    export_to_parquet,
    prepare_data
)
from src.utils import calculate_frequency, validate_data, get_telemetry_fields

# Reload modules to pick up any changes (useful during development)
import src.utils
import src.data_preparation
importlib.reload(src.utils)
importlib.reload(src.data_preparation)

# Re-import after reload
from src.utils import calculate_frequency, validate_data, get_telemetry_fields
from src.data_preparation import (
    load_fastf1_session,
    extract_telemetry_fields,
    export_to_csv,
    export_to_parquet,
    prepare_data
)

print("✅ Imports successful")
# Out:
# ✅ Imports successful
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Load configuration
import yaml

config_path = "../config/config.yaml"
with open(config_path, 'r') as f:
    config = yaml.safe_load(f)

race_config = config['race']
print(f"Race Configuration:")
print(f"  Year: {race_config['year']}")
print(f"  Grand Prix: {race_config['grand_prix']}")
print(f"  Session: {race_config['session']}")
# Out:
# Race Configuration:
#   Year: 2023
#   Grand Prix: Monaco
#   Session: Race

# %%
# Load FastF1 session data
year = race_config['year']
grand_prix = race_config['grand_prix']
session = race_config['session']

print(f"Loading {year} {grand_prix} {session}...")
session_obj = load_fastf1_session(year, grand_prix, session, cache_dir="../../OLD_version/f1_cache")

print(f"✅ Session loaded successfully")
print(f"Drivers: {session_obj.results['Abbreviation'].tolist()}")
# Out:
# INFO:src.data_preparation:Loading 2023 Monaco Race...
# Loading 2023 Monaco Race...
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.6.1]
# INFO:fastf1.fastf1.core:Loading data for Monaco Grand Prix - Race [v3.6.1]
# req            INFO 	Using cached data for session_info
# INFO:fastf1.fastf1.req:Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# INFO:fastf1.fastf1.req:Using cached data for driver_info
# DEBUG:fastf1.ergast:Failed to parse timestamp '-1:53:44.819' in Ergastresponse.
# req            INFO 	Using cached data for session_status_data
# INFO:fastf1.fastf1.req:Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# INFO:fastf1.fastf1.req:Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# INFO:fastf1.fastf1.req:Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# INFO:fastf1.fastf1.req:Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# INFO:fastf1.fastf1.req:Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# INFO:fastf1.fastf1.core:Processing timing data...
# req            INFO 	Using cached data for car_data
# INFO:fastf1.fastf1.req:Using cached data for car_data
# req            INFO 	Using cached data for position_data
# INFO:fastf1.fastf1.req:Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# INFO:fastf1.fastf1.req:Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# INFO:fastf1.fastf1.req:Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '14', '31', '44', '63', '16', '10', '55', '4', '81', '77', '21', '24', '23', '22', '11', '27', '2', '20', '18']
# INFO:fastf1.fastf1.core:Finished loading data for 20 drivers: ['1', '14', '31', '44', '63', '16', '10', '55', '4', '81', '77', '21', '24', '23', '22', '11', '27', '2', '20', '18']
# INFO:src.data_preparation:Session loaded successfully
# ✅ Session loaded successfully
# Drivers: ['VER', 'ALO', 'OCO', 'HAM', 'RUS', 'LEC', 'GAS', 'SAI', 'NOR', 'PIA', 'BOT', 'DEV', 'ZHO', 'ALB', 'TSU', 'PER', 'HUL', 'SAR', 'MAG', 'STR']

# %%
# Extract telemetry fields
print("Extracting telemetry fields...")
df = extract_telemetry_fields(session_obj)

print(f"\n✅ Data extraction complete")
print(f"Total records: {len(df)}")
print(f"Columns: {list(df.columns)}")
print(f"\nFirst few rows:")
df.head()
# Out:
# INFO:src.data_preparation:Extracting telemetry for 20 drivers
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# Extracting telemetry fields...
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:24.238000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:37.420000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.053000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:06.559000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:27.543000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'MEDIUM' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:20.954000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:48.412000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:14:17.451000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:14:41.935000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 49781 data points for driver VER
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:25.527000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:37.981000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.254000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:07.574000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:28.808000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'HARD' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:20.871000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:49.651000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:12:31.906000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:12:56.125000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 49987 data points for driver ALO
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:26.639000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:38.186000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.587000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:08.324000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:29.949000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'MEDIUM' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.245000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:51.118000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:43:44.750000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:44:10.702000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 50055 data points for driver OCO
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:28.585000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:38.830000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.942000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:09.933000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:31.871000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'MEDIUM' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.226000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:53.036000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:42:34.329000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:42:58.797000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 50070 data points for driver HAM
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:30.387000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:39.443000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.744000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:11.933000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:33.699000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'HARD' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.784000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:55.394000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:12:56.843000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:13:27.718000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 50168 data points for driver RUS
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:29.108000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:38.983000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.868000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:10.528000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:32.417000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'HARD' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.352000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:53.697000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:59:24.702000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:59:48.889000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 50249 data points for driver LEC
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:29.701000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:39.087000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.849000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:11.168000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:33.011000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'HARD' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.350000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:54.290000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:03:16.010000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:03:39.885000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 50254 data points for driver GAS
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:27.390000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:38.450000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.607000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:09.074000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:30.683000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# ...
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.570000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:20.136000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:41.636000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'HARD' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:20.988000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:04:02.624000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:19:25.914000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:20:16.992000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 47645 data points for driver MAG
# /Users/Ujjwal/Library/Python/3.9/lib/python/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:01:39.562000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:46.215000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.708000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:21.136000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:03:42.870000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:02:02.950000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-05-28 13:03:03.927000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'HARD' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:135: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:00:21.136000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 01:04:03.924000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:09:52.253000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# /Users/Ujjwal/Documents/DE Project/f1_streaming_pipeline/src/data_preparation.py:133: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 02:10:16.893000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   telemetry.loc[lap_mask, field] = value
# INFO:src.data_preparation:Extracted 32788 data points for driver STR
# WARNING:src.data_preparation:Error merging weather data: 'SessionTime_seconds'
# INFO:src.data_preparation:Merged driver/session info: 12 fields
# INFO:src.data_preparation:Total telemetry data points: 982330
# INFO:src.data_preparation:Total columns: 65
# INFO:src.data_preparation:Columns: ['Date', 'SessionTime', 'DriverAhead', 'DistanceToDriverAhead', 'Time', 'RPM', 'Speed', 'nGear', 'Throttle', 'Brake', 'DRS', 'Source', 'Distance', 'RelativeDistance', 'Status_x', 'X', 'Y', 'Z', 'DriverID', 'Driver', 'LapNumber', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime', 'LapStartTime', 'LapStartDate', 'PitOutTime', 'PitInTime', 'IsPersonalBest', 'Compound', 'TyreLife', 'FreshTyre', 'Stint', 'TrackStatus', 'Position_x', 'Deleted', 'DeletedReason', 'LapTime_seconds', 'Sector2Time_seconds', 'Sector3Time_seconds', 'Sector2SessionTime_seconds', 'Sector3SessionTime_seconds', 'LapStartTime_seconds', 'Time_seconds', 'Sector1Time_seconds', 'Sector1SessionTime_seconds', 'PitInTime_seconds', 'PitOutTime_seconds', 'SessionTime_seconds', 'DriverNumber', 'FullName', 'FirstName', 'LastName', 'TeamName', 'GridPosition', 'Position_y', 'Points', 'Status_y', 'Q1', 'Q2', 'Q3']
# ✅ Data extraction complete
# Total records: 982330
# Columns: ['Date', 'SessionTime', 'DriverAhead', 'DistanceToDriverAhead', 'Time', 'RPM', 'Speed', 'nGear', 'Throttle', 'Brake', 'DRS', 'Source', 'Distance', 'RelativeDistance', 'Status_x', 'X', 'Y', 'Z', 'DriverID', 'Driver', 'LapNumber', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime', 'LapStartTime', 'LapStartDate', 'PitOutTime', 'PitInTime', 'IsPersonalBest', 'Compound', 'TyreLife', 'FreshTyre', 'Stint', 'TrackStatus', 'Position_x', 'Deleted', 'DeletedReason', 'LapTime_seconds', 'Sector2Time_seconds', 'Sector3Time_seconds', 'Sector2SessionTime_seconds', 'Sector3SessionTime_seconds', 'LapStartTime_seconds', 'Time_seconds', 'Sector1Time_seconds', 'Sector1SessionTime_seconds', 'PitInTime_seconds', 'PitOutTime_seconds', 'SessionTime_seconds', 'DriverNumber', 'FullName', 'FirstName', 'LastName', 'TeamName', 'GridPosition', 'Position_y', 'Points', 'Status_y', 'Q1', 'Q2', 'Q3']
#
# First few rows:
#                      Date            SessionTime DriverAhead  \
# 0 2023-05-28 13:03:03.927 0 days 01:02:02.950000
# 1 2023-05-28 13:03:03.927 0 days 01:02:02.950000
# 2 2023-05-28 13:03:03.927 0 days 01:02:02.950000
# 3 2023-05-28 13:03:03.927 0 days 01:02:02.950000
# 4 2023-05-28 13:03:03.927 0 days 01:02:02.950000
#
#    DistanceToDriverAhead                   Time           RPM  Speed  nGear  \
# 0               0.066667 0 days 01:03:27.435000  10058.716787    0.0      1
# 1               0.000000 0 days 01:03:28.724000   9551.783309    0.0      1
# 2               0.000000 0 days 01:03:32.305000  10395.508211    0.0      1
# 3               0.000000 0 days 01:03:30.587000  10236.883379    0.0      1
# 4               0.000000 0 days 01:04:03.289000  11255.425011    0.0      1
#
#    Throttle  Brake  ...  FirstName    LastName         TeamName  GridPosition  \
# 0      16.0   True  ...        Max  Verstappen  Red Bull Racing           1.0
# 1      25.0  False  ...   Fernando      Alonso     Aston Martin           2.0
# 2      38.0   True  ...    Charles     Leclerc          Ferrari           6.0
# 3      30.0  False  ...     Carlos       Sainz          Ferrari           4.0
# 4      24.0  False  ...       Nico  Hulkenberg     Haas F1 Team          18.0
#
#   Position_y  Points  Status_y  Q1  Q2  Q3
# 0        1.0    25.0  Finished NaT NaT NaT
# 1        2.0    18.0  Finished NaT NaT NaT
# 2        6.0     8.0  Finished NaT NaT NaT
# 3        8.0     4.0  Finished NaT NaT NaT
# 4       17.0     0.0    Lapped NaT NaT NaT
#
# [5 rows x 65 columns]

# %%
# Calculate data frequency from timestamps
if 'SessionTime' in df.columns:
    frequency = calculate_frequency(df['SessionTime'])
    print(f"✅ Data frequency calculated: {frequency:.2f} Hz (avg interval: {1000/frequency:.2f} ms)")
else:
    print("⚠️ Warning: SessionTime column not found, cannot calculate frequency")
# Out:
# INFO:src.utils:Calculated frequency: 7.62 Hz (avg interval: 131.18 ms)
# ✅ Data frequency calculated: 7.62 Hz (avg interval: 131.18 ms)

# %%
# Validate data
required_fields = ['SessionTime', 'DriverID', 'Speed']
is_valid, error_msg = validate_data(df, required_fields)

if is_valid:
    print("✅ Data validation passed")
    print(f"Required fields present: {required_fields}")
else:
    print(f"❌ Data validation failed: {error_msg}")
# Out:
# ✅ Data validation passed
# Required fields present: ['SessionTime', 'DriverID', 'Speed']

# %%
# Export to CSV (Parquet is optional - CSV is sufficient for the pipeline)
data_dir = "../data"
os.makedirs(data_dir, exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
base_filename = f"{year}_{grand_prix}_{session}_{timestamp}"

# Export to CSV (required)
csv_path = os.path.join(data_dir, f"{base_filename}.csv")
if export_to_csv(df, csv_path):
    print(f"✅ CSV exported: {csv_path}")
else:
    print("❌ Failed to export CSV")

# Export to Parquet (optional - skip if it fails)
parquet_path = os.path.join(data_dir, f"{base_filename}.parquet")
parquet_success = False
try:
    if export_to_parquet(df, parquet_path):
        print(f"✅ Parquet exported: {parquet_path}")
        parquet_success = True
    else:
        print("⚠️ Parquet export failed (optional - CSV is sufficient)")
except Exception as e:
    print(f"⚠️ Parquet export skipped due to error: {e}")
    print("   Note: CSV file is sufficient for the pipeline")

# Display summary
print(f"\n📊 Data Summary:")
print(f"  Total records: {len(df)}")
print(f"  Drivers: {df['DriverID'].unique().tolist() if 'DriverID' in df.columns else 'N/A'}")
print(f"  Frequency: {frequency:.2f} Hz" if 'frequency' in locals() else "  Frequency: N/A")
print(f"  CSV file: {csv_path} ✅")
if parquet_success:
    print(f"  Parquet file: {parquet_path} ✅")
else:
    print(f"  Parquet file: Skipped (optional)")
# Out:
# INFO:src.data_preparation:Exported 982330 rows, 65 columns to CSV: ../data/2023_Monaco_Race_20251119_182219.csv
# ✅ CSV exported: ../data/2023_Monaco_Race_20251119_182219.csv
# INFO:src.data_preparation:Exported 982330 rows to Parquet: ../data/2023_Monaco_Race_20251119_182219.parquet
# ✅ Parquet exported: ../data/2023_Monaco_Race_20251119_182219.parquet
#
# 📊 Data Summary:
#   Total records: 982330
#   Drivers: ['VER', 'ALO', 'LEC', 'SAI', 'HUL', 'STR', 'TSU', 'HAM', 'DEV', 'MAG', 'ZHO', 'BOT', 'PER', 'OCO', 'ALB', 'PIA', 'SAR', 'GAS', 'NOR', 'RUS']
#   Frequency: 7.62 Hz
#   CSV file: ../data/2023_Monaco_Race_20251119_182219.csv ✅
#   Parquet file: ../data/2023_Monaco_Race_20251119_182219.parquet ✅

# %%
# Validate exported files can be loaded
print("Validating exported files...")

# Load CSV (required)
df_csv = pd.read_csv(csv_path)
print(f"✅ CSV loaded: {len(df_csv)} rows, {len(df_csv.columns)} columns")

# Verify CSV data integrity
if len(df_csv) == len(df):
    print("✅ CSV data integrity verified: Row count matches original data")
else:
    print(f"⚠️ Warning: Row count mismatch (CSV: {len(df_csv)}, Original: {len(df)})")

# Try to load Parquet if it exists (optional validation)
parquet_path_exists = os.path.exists(parquet_path) and os.path.getsize(parquet_path) > 0
if parquet_path_exists:
    try:
        df_parquet = pd.read_parquet(parquet_path, engine='pyarrow')
        print(f"✅ Parquet loaded: {len(df_parquet)} rows, {len(df_parquet.columns)} columns")
        
        # Verify Parquet data integrity
        if len(df_parquet) == len(df):
            print("✅ Parquet data integrity verified: Row count matches original data")
        else:
            print(f"⚠️ Warning: Parquet row count mismatch (Parquet: {len(df_parquet)}, Original: {len(df)})")
    except Exception as e:
        print(f"⚠️ Parquet file exists but could not be loaded: {e}")
        print("   Note: This is optional - CSV file is sufficient for the pipeline")
else:
    print("ℹ️  Parquet file not available (optional - CSV is sufficient)")

print("\n✅ Step 1 Complete: Data preparation successful!")
print("   CSV file is ready for use in subsequent steps (cache setup, Kafka producer, etc.)")
# Out:
# Validating exported files...
# /var/folders/wb/cymgctss1x796vs1cd3z77nc0000gp/T/ipykernel_98664/4277942406.py:5: DtypeWarning: Columns (32,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_csv = pd.read_csv(csv_path)
# ✅ CSV loaded: 982330 rows, 65 columns
# ✅ CSV data integrity verified: Row count matches original data
# ✅ Parquet loaded: 982330 rows, 65 columns
# ✅ Parquet data integrity verified: Row count matches original data
#
# ✅ Step 1 Complete: Data preparation successful!
#    CSV file is ready for use in subsequent steps (cache setup, Kafka producer, etc.)
