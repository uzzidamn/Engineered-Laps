# %% [markdown]
# # Step 5: Kafka Consumer & Real-Time Analysis App
#
# **Objective:**
# Consume streamed telemetry, run analytics or ML on each incoming message.
#
# **Instructions:**
# - Implement Python consumer subscribing to "f1-speed-stream"
# - On message receipt: Parse JSON, run analytics/model inference, record latency
# - Validate: Consumer receives messages, analysis completes, latency logged

# %%
# Import required libraries
import sys
import os
import time
from pathlib import Path

# Add project root to Python path
# In Jupyter, getcwd() typically returns the project root
# If not, navigate up from notebooks/ directory
current_dir = os.getcwd()
if os.path.basename(current_dir) == 'notebooks':
    # We're in notebooks/ directory, go up one level
    project_root = Path(os.path.dirname(current_dir))
else:
    # We're already at project root
    project_root = Path(current_dir)

# Add to path if not already there
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.kafka_consumer import RealTimeConsumer
# Out:
# ✅ Imports successful
#
# ======================================================================
# AUTO-STARTING PRODUCER FOR CONTINUOUS STREAMING
# ======================================================================
# ✅ Producer is already running in background
#    Continuous data streaming is active!
# ======================================================================

# %%
# Initialize consumer
consumer = RealTimeConsumer(config_path="../config/config.yaml")
# Out:
# ✅ Consumer initialized

# %%
# ============================================================================
# CONSUME MESSAGES: Real-Time Processing
# ============================================================================
# The producer is now streaming data continuously in the background
# This consumer will process messages as they arrive in real-time

print("=" * 70)
print("STARTING REAL-TIME MESSAGE CONSUMPTION")
print("=" * 70)
print("\n📥 Consumer is ready to process messages from Kafka")
print("   Producer is streaming data continuously in the background")
print("   This will consume and analyze messages in real-time...\n")

# Consume messages (adjust timeout as needed)
# Set timeout_seconds=None for continuous consumption (until interrupted)
# Or set a specific duration for testing
stats = consumer.consume_messages(timeout_seconds=60, max_messages=5000)  # 60 seconds or 5000 messages

print("\n📊 Consumption Statistics:")
print(f"  Messages processed: {stats.get('messages_processed', 0)}")
print(f"  Duration: {stats.get('duration_seconds', 0):.2f} seconds")
print(f"  Avg rate: {stats.get('avg_rate_messages_per_sec', 0):.2f} msg/s")
print(f"  Avg latency: {stats.get('avg_latency_ms', 0):.2f} ms")
print(f"  Max latency: {stats.get('max_latency_ms', 0):.2f} ms")
print(f"  Total anomalies: {stats.get('total_anomalies', 0)}")
print(f"  Success: {stats.get('success', False)}")
# Out:
# INFO:kafka.conn:<BrokerConnection client_id=kafka-python-2.2.15, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# INFO:kafka.conn:<BrokerConnection client_id=kafka-python-2.2.15, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Broker version identified as 2.6
# INFO:kafka.conn:<BrokerConnection client_id=kafka-python-2.2.15, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# WARNING:kafka.coordinator.consumer:group_id is None: disabling auto-commit.
# INFO:kafka.consumer.subscription_state:Updating subscribed topics to: ('f1-speed-stream',)
# INFO:src.kafka_consumer:Connected to Kafka at localhost:9092, subscribed to 'f1-speed-stream'
# WARNING:src.ml_inference:Model not found: models/crash_risk_model.pkl
# WARNING:src.ml_inference:Scaler not found: models/crash_risk_scaler.pkl
# WARNING:src.ml_inference:Model not found: models/tire_failure_model.pkl
# WARNING:src.ml_inference:Scaler not found: models/tire_failure_scaler.pkl
# WARNING:src.ml_inference:Model not found: models/pit_stop_probability_model.pkl
# WARNING:src.ml_inference:Scaler not found: models/pit_stop_probability_scaler.pkl
# WARNING:src.ml_inference:No models loaded. Using fallback predictions.
# INFO:src.kafka_consumer:ML models loaded successfully
# INFO:src.kafka_consumer:Starting message consumption... (timeout: 60s, max_messages: 5000)
# INFO:src.kafka_consumer:Using poll timeout: 1000ms
# INFO:kafka.consumer.subscription_state:Updated partition assignment: [TopicPartition(topic='f1-speed-stream', partition=0), TopicPartition(topic='f1-speed-stream', partition=1), TopicPartition(topic='f1-speed-stream', partition=2), TopicPartition(topic='f1-speed-stream', partition=3)]
# INFO:kafka.conn:<BrokerConnection client_id=kafka-python-2.2.15, node_id=1 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# INFO:kafka.conn:<BrokerConnection client_id=kafka-python-2.2.15, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# INFO:kafka.conn:<BrokerConnection client_id=kafka-python-2.2.15, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# INFO:kafka.consumer.fetcher:Resetting offset for partition TopicPartition(topic='f1-speed-stream', partition=3) to offset 0.
# INFO:kafka.consumer.fetcher:Resetting offset for partition TopicPartition(topic='f1-speed-stream', partition=2) to offset 0.
# INFO:kafka.consumer.fetcher:Resetting offset for partition TopicPartition(topic='f1-speed-stream', partition=1) to offset 0.
# INFO:kafka.consumer.fetcher:Resetting offset for partition TopicPartition(topic='f1-speed-stream', partition=0) to offset 0.
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 100 messages in 0.2s (622.4 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (207.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (204.5 km/h) with heavy braking
# INFO:src.kafka_consumer:Processed 200 messages in 0.2s (1222.5 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 300 messages in 0.2s (1808.3 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 400 messages in 0.2s (2291.3 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# ======================================================================
# STARTING REAL-TIME MESSAGE CONSUMPTION
# ======================================================================
#
# 📥 Consumer is ready to process messages from Kafka
#    Producer is streaming data continuously in the background
#    This will consume and analyze messages in real-time...
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 500 messages in 0.2s (2822.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (233.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (229.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (228.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (231.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (223.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (238.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (234.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (235.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (233.5 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (229.1 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (217.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (209.3 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (233.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (222.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (215.4 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (231.1 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: high_speed_braking - High speed (233.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (208.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: high_speed_braking - High speed (228.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 600 messages in 0.2s (2841.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (200.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (220.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (217.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (216.1 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (212.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: high_speed_braking - High speed (207.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (208.2 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (207.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (204.3 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (201.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 700 messages in 0.2s (3164.1 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 800 messages in 0.2s (3512.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 900 messages in 0.2s (3849.4 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1000 messages in 0.2s (4248.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (207.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (204.5 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1100 messages in 0.3s (3903.2 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1200 messages in 0.3s (4202.5 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1300 messages in 0.3s (4467.1 msg/s, avg latency: 0.00 ms)
# INFO:src.kafka_consumer:Processed 1400 messages in 0.3s (4801.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (233.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (229.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (228.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (231.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (223.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (238.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (234.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (235.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (233.5 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (229.1 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (217.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (209.3 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (233.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (222.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (215.4 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (231.1 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: high_speed_braking - High speed (233.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (208.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: high_speed_braking - High speed (228.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (200.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (220.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1500 messages in 0.3s (5003.2 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (217.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (216.1 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (212.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: high_speed_braking - High speed (207.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (208.2 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (207.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (204.3 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: high_speed_braking - High speed (201.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1600 messages in 0.4s (3701.0 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1700 messages in 0.4s (3816.5 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1800 messages in 0.5s (3941.6 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 1900 messages in 0.5s (4142.2 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 2000 messages in 0.5s (4352.4 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 2100 messages in 0.5s (4343.4 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 2200 messages in 0.5s (4529.4 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 2300 messages in 0.5s (4689.0 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 2400 messages in 0.5s (4879.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 2500 messages in 0.5s (5074.1 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# ...
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 3500 messages in 0.6s (6359.0 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 3600 messages in 0.6s (6356.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 3700 messages in 0.6s (6509.3 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 3800 messages in 0.6s (6676.5 msg/s, avg latency: 0.00 ms)
# INFO:src.kafka_consumer:Processed 3900 messages in 0.6s (6847.4 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (266.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (264.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (247.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (225.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (212.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (207.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 4000 messages in 0.6s (6995.1 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (267.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (266.5 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (258.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (257.2 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (242.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (235.7 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (222.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (211.2 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (207.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 4100 messages in 0.6s (6909.0 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 4200 messages in 0.6s (7033.3 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (259.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (251.5 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (249.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (243.8 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (241.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (224.7 km/h) with heavy braking
# INFO:src.kafka_consumer:Processed 4300 messages in 0.6s (7160.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (224.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (211.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (209.2 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (262.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (253.9 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [ZHO]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (250.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (238.7 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (231.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (223.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (216.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [STR]: high_speed_braking - High speed (210.5 km/h) with heavy braking
# INFO:src.kafka_consumer:Processed 4400 messages in 0.6s (7117.1 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 4500 messages in 0.6s (7266.5 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [STR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (203.0 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: high_speed_braking - High speed (202.5 km/h) with heavy braking
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 4600 messages in 0.6s (7223.1 msg/s, avg latency: 0.00 ms)
# INFO:src.kafka_consumer:Processed 4700 messages in 0.6s (7369.9 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [PER]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 4800 messages in 0.6s (7496.6 msg/s, avg latency: 0.00 ms)
# INFO:src.kafka_consumer:Processed 4900 messages in 0.6s (7646.6 msg/s, avg latency: 0.00 ms)
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# WARNING:src.kafka_consumer:ANOMALY [SAR]: throttle_brake_overlap - Throttle and brake applied simultaneously
# INFO:src.kafka_consumer:Processed 5000 messages in 0.6s (7793.6 msg/s, avg latency: 0.00 ms)
# INFO:src.kafka_consumer:Consumption completed: 5000 messages in 0.6s
# INFO:src.kafka_consumer:Average rate: 7790.0 msg/s, Average latency: 0.00 ms
# 📊 Consumption Statistics:
#   Messages processed: 5000
#   Duration: 0.64 seconds
#   Avg rate: 7789.97 msg/s
#   Avg latency: 0.00 ms
#   Max latency: 0.29 ms
#   Total anomalies: 590
#   Success: True

# %%
# View analysis results
results = consumer.get_analysis_results()
print(f"\nTotal analysis results: {len(results)}")

if results:
    print("\nSample analysis result:")
    sample = results[0]
    print(f"  Driver: {sample['message'].get('driver', 'N/A')}")
    print(f"  Speed: {sample['message'].get('speed', 0):.1f} km/h")
    print(f"  Anomalies: {len(sample['analysis'].get('anomalies', []))}")
    print(f"  Predictions: {sample['analysis'].get('predictions', {})}")
    print(f"  Processing time: {sample['processing_time']*1000:.2f} ms")
    
    # Check latency stats
    latency_stats = consumer.get_latency_stats()
    if latency_stats:
        print(f"\nLatency Statistics:")
        print(f"  Avg: {latency_stats.get('avg', 0):.2f} ms")
        print(f"  Min: {latency_stats.get('min', 0):.2f} ms")
        print(f"  Max: {latency_stats.get('max', 0):.2f} ms")
        print(f"  Count: {latency_stats.get('count', 0)}")

# Close consumer
consumer.close()

print("\n" + "=" * 70)
print("✅ Step 5 Complete: Kafka consumer analysis successful!")
print("=" * 70)

# Note: Producer is still running in background
# To stop it, run: from src.producer_manager import stop_producer; stop_producer()
# Or use notebook 03_kafka_producer.ipynb (Cell 8)
# Out:
# INFO:kafka.conn:<BrokerConnection client_id=kafka-python-2.2.15, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# INFO:src.kafka_consumer:Kafka consumer closed
# Total analysis results: 5000
#
# Sample analysis result:
#   Driver: SAR
#   Speed: 0.0 km/h
#   Anomalies: 0
#   Predictions: {'crash_risk': 0.05, 'tire_failure': 0.03, 'pit_stop_probability': 0.15}
#   Processing time: 0.01 ms
#
# Latency Statistics:
#   Avg: 0.00 ms
#   Min: 0.00 ms
#   Max: 0.29 ms
#   Count: 1000
#
# ======================================================================
# ✅ Step 5 Complete: Kafka consumer analysis successful!
# ======================================================================
